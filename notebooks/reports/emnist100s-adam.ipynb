# %%
import os
os.chdir('../..')

# %%
import comet_ml
from comet_ml.exceptions import NotFound
from comet_ml.query import Parameter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import holoviews as hv

import viz

# %%
hv.extension('matplotlib')
comet_api = comet_ml.api.API()
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
viz.generate_single_plot(comet_api, "adam", "a", "adam", E=1) + viz.generate_single_plot(comet_api, "adam", "a", "adam", E=5)
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .HeatMap.I :HeatMap   [Client Learning Rate (log10),Server Learning Rate (log10)]   (Accuracy)
#       .Ellipse.I :Ellipse   [x,y]
#    .Overlay.II :Overlay
#       .HeatMap.I :HeatMap   [Client Learning Rate (log10),Server Learning Rate (log10)]   (Accuracy)
#       .Ellipse.I :Ellipse   [x,y]

# %%
viz.generate_single_plot(comet_api, "sgd", "a", "adam", E=1) + viz.generate_single_plot(comet_api, "sgd", "a", "adam", E=5)

# %%
viz.generate_single_plot(comet_api, "sgd", E=1) + viz.generate_single_plot(comet_api, "sgd", E=5)

# %%
viz.generate_single_plot(comet_api, "adam", E=1) + viz.generate_single_plot(comet_api, "adam", E=5)

# %%
# viz.save_plot(comet_api, "SGD", "a", "SGDM")
# viz.save_plot(comet_api, "Yogi", "a", "Yogi")
# viz.save_plot(comet_api, "SGD", "a", "Yogi")
# viz.save_plot(comet_api, "SGD")
# viz.save_plot(comet_api, "Yogi")

# %%
viz.generate_plot(comet_api, "sgd", "a", "adam")

# %%
viz.generate_plot(comet_api, "sgd")

# %%
viz.generate_plot(comet_api, "adam")
